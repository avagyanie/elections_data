# %%
import pandas as pd

df = pd.read_csv("elections.csv")
df
# Out:
# C:\Users\hayk_\AppData\Local\Temp\ipykernel_21372\970442066.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("elections.csv")
#                azganun        anun haeranun or_amis_tari    marz   hamaenq  \
# 0        Հարությունյան       Կարեն   Շաքարի   14/11/1997  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 1            Աղաջանյան      Կարինե   Ժորայի   14/08/1964  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 2        Հարությունյան  Հարություն   Շաքարի   29/10/1986  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 3           Ալեքսանյան      Համեստ   Արսենի   24/10/1954  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 4        Հարությունյան       Շաքար   Արտաշի   01/01/1959  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# ...                ...         ...      ...          ...     ...       ...
# 2577168     Շահվերդյան         Ալա   Աղասու   22/04/1987    ԼՈՌԻ   ՎԱՆԱՁՈՐ
# 2577169      Իսրաելյան      Կարինե   Վահանի   13/03/1960    ԼՈՌԻ     ԴԵԲԵԴ
# 2577170      Գրիգորյան      Անահիտ  Հունանի   12/05/1970    ԼՈՌԻ   ՎԱՆԱՁՈՐ
# 2577171       Սահակյան      Նարինե    Աշոտի   25/09/1978    ԼՈՌԻ   ՎԱՆԱՁՈՐ
# 2577172       Մկրտչյան      Գայանե  Գարուշի   24/04/1966    ԼՈՌԻ   ՎԱՆԱՁՈՐ
#
#         bnakavaer                      hasce  taracq texamas
# 0             NaN        Չարենցի Փ.   31   1      28   28/01
# 1             NaN        Չարենցի Փ.   31   1      28   28/01
# 2             NaN        Չարենցի Փ.   31   1      28   28/01
# 3             NaN       Չարենցի Փ.   26   71      28   28/01
# 4             NaN        Չարենցի Փ.   31   1      28   28/01
# ...           ...                        ...     ...     ...
# 2577168       NaN            1 Փ. 5 Փկղ.   8      23   23/58
# 2577169       NaN                   6 Փ.   5      23   23/58
# 2577170       NaN        Արճիս  5 Փ.   7   1      23   23/58
# 2577171       NaN  Կ. Դեմիրճյան Փ.   26   22      23   23/58
# 2577172       NaN     Տարոն 3 Քշհ 7   48   7      23   23/58
#
# [2577173 rows x 10 columns]

# %%
# !uv pip install pyarrow
# Out:
# Using Python 3.10.18 environment at: C:\Users\hayk_\.conda\envs\lectures
# Resolved 1 package in 309ms
# Downloading pyarrow (24.6MiB)
#  Downloading pyarrow
# Prepared 1 package in 3.90s
# Installed 1 package in 890ms
#  + pyarrow==20.0.0

# %%
df.to_parquet("elections.parquet")

# %%
from pathlib import Path

parqeut_file = Path("elections.parquet")

# file size
file_size = parqeut_file.stat().st_size
print(f"File size: {file_size / (1024 * 1024):.2f} MB")
# Out:
# File size: 27.90 MB

# %%
# !uv pip install tabulate
# Out:
# Using Python 3.10.18 environment at: C:\Users\hayk_\.conda\envs\lectures
# Resolved 1 package in 196ms
# Prepared 1 package in 75ms
# Installed 1 package in 28ms
#  + tabulate==0.9.0

# %%
# shuffle some columns
df = df.sample(frac=1).reset_index(drop=True)
# Out:
# '|    | azganun    | anun   | haeranun   | or_amis_tari   | marz        | hamaenq   |   bnakavaer | hasce            |   taracq | texamas   |\n|---:|:-----------|:-------|:-----------|:---------------|:------------|:----------|------------:|:-----------------|---------:|:----------|\n|  0 | Բիլբուլյան | Մելս   | Բիլբուլի   | 15/04/1953     | ԱՐՄԱՎԻՐ     | ՀՈՒՇԱԿԵՐՏ |         nan | 5 Փ.   5         |       16 | 16/50     |\n|  1 | Սահակյան   | Անահիտ | Ջոնի       | 22/03/2001     | ԳԵՂԱՐՔՈՒՆԻՔ | ԾՈՎԻՆԱՐ   |         nan | 5 Թղմ. 14 Փ.   8 |       21 | 21/36     |'

# %%
print(df.head(2).to_markdown())
# Out:
# |    | azganun    | anun   | haeranun   | or_amis_tari   | marz        | hamaenq   |   bnakavaer | hasce            |   taracq | texamas   |
# |---:|:-----------|:-------|:-----------|:---------------|:------------|:----------|------------:|:-----------------|---------:|:----------|
# |  0 | Բիլբուլյան | Մելս   | Բիլբուլի   | 15/04/1953     | ԱՐՄԱՎԻՐ     | ՀՈՒՇԱԿԵՐՏ |         nan | 5 Փ.   5         |       16 | 16/50     |
# |  1 | Սահակյան   | Անահիտ | Ջոնի       | 22/03/2001     | ԳԵՂԱՐՔՈՒՆԻՔ | ԾՈՎԻՆԱՐ   |         nan | 5 Թղմ. 14 Փ.   8 |       21 | 21/36     |
